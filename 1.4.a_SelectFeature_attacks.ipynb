# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time

# %matplotlib inline
seconds = time.time()


def folder(f_name):
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print("The folder could not be created!")


csv_files = os.listdir("/content/drive/MyDrive/ISU/attacks/")

main_labels = ["Flow Duration", "Tot Fwd Pkts", "Tot Bwd Pkts", "TotLen Fwd Pkts", "TotLen Bwd Pkts", "Fwd Pkt Len Max",
               "Fwd Pkt Len Min", "Fwd Pkt Len Mean", "Fwd Pkt Len Std", "Bwd Pkt Len Max", "Bwd Pkt Len Min",
               "Bwd Pkt Len Mean", "Bwd Pkt Len Std", "Flow Byts/s", "Flow Pkts/s", "Flow IAT Mean", "Flow IAT Std",
               "Flow IAT Max", "Flow IAT Min", "Fwd IAT Tot", "Fwd IAT Mean", "Fwd IAT Std", "Fwd IAT Max",
               "Fwd IAT Min", "Bwd IAT Tot", "Bwd IAT Mean", "Bwd IAT Std", "Bwd IAT Max", "Bwd IAT Min",
               "Fwd PSH Flags", "Bwd PSH Flags", "Fwd URG Flags", "Bwd URG Flags", "Fwd Header Len", "Bwd Header Len",
               "Fwd Pkts/s", "Bwd Pkts/s", "Pkt Len Min", "Pkt Len Max", "Pkt Len Mean", "Pkt Len Std", "Pkt Len Var",
               "FIN Flag Cnt", "SYN Flag Cnt", "RST Flag Cnt", "PSH Flag Cnt", "ACK Flag Cnt", "URG Flag Cnt",
               "CWE Flag Count", "ECE Flag Cnt", "Down/Up Ratio", "Pkt Size Avg", "Fwd Seg Size Avg",
               "Bwd Seg Size Avg", "Fwd Byts/b Avg", "Fwd Pkts/b Avg", "Fwd Blk Rate Avg", "Bwd Byts/b Avg",
               "Bwd Pkts/b Avg", "Bwd Blk Rate Avg", "Subflow Fwd Pkts", "Subflow Fwd Byts", "Subflow Bwd Pkts",
               "Subflow Bwd Byts", "Init Fwd Win Byts", "Init Bwd Win Byts", "Fwd Act Data Pkts", "Fwd Seg Size Min",
               "Active Mean", "Active Std", "Active Max", "Active Min", "Idle Mean", "Idle Std", "Idle Max", "Idle Min",
               "Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("/content/drive/MyDrive/ISU/feature_pics_attack/")

for j in csv_files:
    df = pd.read_csv("/content/drive/MyDrive/ISU/attacks/" + j, usecols=main_labels)
    df.fillna(0, inplace=True)
    df.replace([np.inf, -np.inf], -1, inplace=True)
    attack_or_not = []

    for i in df["Label"]:
        if i == "Benign":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)

    df["Label"] = attack_or_not
    y = df["Label"].values
    del df["Label"]
    X = df.values
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0

    forest = sk.ensemble.RandomForestRegressor(n_estimators=250, random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol = list(df.columns.values)
    impor_bars = pd.DataFrame({'Features': refclasscol[0:20], 'importance': importances[0:20]})
    impor_bars = impor_bars.sort_values('importance', ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();

    count = 0
    fea_ture = j[0:-4] + "=["

    for i in impor_bars.index:
        fea_ture = fea_ture + "\"" + str(i) + "\","
        count += 1
        if count == 5:
            fea_ture = fea_ture[0:-1] + "]"
            break

    print(j[0:-4], "importance list:")
    print(j[0:-4], "\n", impor_bars.head(20), "\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4] + " Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("/content/drive/MyDrive/ISU/feature_pics_attack/" + j[0:-4] + ".pdf", bbox_inches='tight',
                papertype='a4', orientation='portrait', format='pdf')
    ths.write((fea_ture))
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

print("Mission accomplished!")
print("Total operation time: = ", time.time() - seconds, "seconds")
ths.close()
# Out:
# DDOS attack-HOIC importance list:
# DDOS attack-HOIC
#                      importance
# Features
# Flow Duration     1.241151e-01
# Bwd Pkt Len Std   1.815133e-03
# Fwd IAT Tot       1.267766e-03
# Flow IAT Max      5.069725e-04
# TotLen Bwd Pkts   1.319778e-04
# Bwd Pkt Len Max   9.234214e-05
# Bwd Pkt Len Mean  8.070553e-05
# Tot Bwd Pkts      3.704046e-05
# Flow IAT Mean     1.732491e-05
# Fwd Pkt Len Mean  1.256552e-05
# Flow Pkts/s       1.048869e-05
# Flow IAT Min      6.704170e-06
# Fwd Pkt Len Std   6.684010e-06
# Flow IAT Std      3.458672e-06
# Tot Fwd Pkts      3.356214e-06
# Flow Byts/s       1.184531e-06
# TotLen Fwd Pkts   1.087011e-06
# Fwd Pkt Len Min   5.441973e-08
# Fwd Pkt Len Max   0.000000e+00
# Bwd Pkt Len Min   0.000000e+00
#
#
#
# DDOS attack-HOIC=["Flow Duration","Bwd Pkt Len Std","Fwd IAT Tot","Flow IAT Max","TotLen Bwd Pkts"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS attacks-Hulk importance list:
# DoS attacks-Hulk
#                      importance
# Features
# Flow IAT Min      1.089702e-02
# Bwd Pkt Len Std   3.082569e-03
# Fwd Pkt Len Max   5.388246e-04
# TotLen Bwd Pkts   3.611448e-04
# Bwd Pkt Len Max   3.303894e-04
# TotLen Fwd Pkts   3.102713e-04
# Bwd Pkt Len Mean  2.319785e-04
# Fwd Pkt Len Std   2.206112e-04
# Fwd Pkt Len Mean  1.843417e-04
# Flow Byts/s       5.698306e-05
# Tot Bwd Pkts      1.648394e-05
# Tot Fwd Pkts      1.412411e-06
# Flow IAT Max      4.413142e-07
# Flow IAT Mean     3.950185e-07
# Flow Pkts/s       1.445898e-07
# Flow Duration     8.432088e-08
# Fwd IAT Tot       8.310893e-08
# Flow IAT Std      4.965224e-08
# Fwd Pkt Len Min   0.000000e+00
# Bwd Pkt Len Min   0.000000e+00
#
#
#
# DoS attacks-Hulk=["Flow IAT Min","Bwd Pkt Len Std","Fwd Pkt Len Max","TotLen Bwd Pkts","Bwd Pkt Len Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Bot importance list:
# Bot
#                      importance
# Features
# Bwd Pkt Len Mean  2.009093e-01
# Flow Pkts/s       1.835651e-01
# Flow IAT Mean     3.522896e-02
# Flow IAT Min      1.356229e-02
# Fwd Pkt Len Mean  9.968490e-03
# Tot Fwd Pkts      4.494562e-04
# Flow Duration     2.238704e-04
# Flow Byts/s       1.344704e-04
# Flow IAT Max      1.052341e-04
# Fwd IAT Tot       9.359044e-05
# TotLen Bwd Pkts   9.020891e-05
# Flow IAT Std      6.237520e-05
# Bwd Pkt Len Max   5.041657e-05
# Tot Bwd Pkts      3.819902e-05
# Bwd Pkt Len Std   1.649825e-05
# Fwd Pkt Len Std   1.495023e-05
# TotLen Fwd Pkts   1.078221e-05
# Fwd Pkt Len Max   1.051658e-05
# Fwd Pkt Len Min   1.604145e-06
# Bwd Pkt Len Min   1.895646e-07
#
#
#
# Bot=["Bwd Pkt Len Mean","Flow Pkts/s","Flow IAT Mean","Flow IAT Min","Fwd Pkt Len Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-BruteForce importance list:
# FTP-BruteForce
#                    importance
# Features
# Flow IAT Mean       0.003776
# Flow Duration       0.003270
# Flow IAT Max        0.002891
# Tot Fwd Pkts        0.000000
# Flow IAT Min        0.000000
# Flow IAT Std        0.000000
# Flow Pkts/s         0.000000
# Flow Byts/s         0.000000
# Bwd Pkt Len Std     0.000000
# Bwd Pkt Len Mean    0.000000
# Bwd Pkt Len Min     0.000000
# Bwd Pkt Len Max     0.000000
# Fwd Pkt Len Std     0.000000
# Fwd Pkt Len Mean    0.000000
# Fwd Pkt Len Min     0.000000
# Fwd Pkt Len Max     0.000000
# TotLen Bwd Pkts     0.000000
# TotLen Fwd Pkts     0.000000
# Tot Bwd Pkts        0.000000
# Fwd IAT Tot         0.000000
#
#
#
# FTP-BruteForce=["Flow IAT Mean","Flow Duration","Flow IAT Max","Tot Fwd Pkts","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Bruteforce importance list:
# SSH-Bruteforce
#                      importance
# Features
# Flow IAT Max      3.607659e-05
# Flow Duration     3.512351e-05
# Flow Pkts/s       3.173986e-05
# Flow IAT Mean     2.896687e-05
# Fwd Pkt Len Std   3.264927e-06
# Tot Fwd Pkts      3.213747e-06
# TotLen Bwd Pkts   3.109773e-06
# Fwd Pkt Len Max   3.097597e-06
# Flow IAT Min      2.741146e-06
# Fwd IAT Tot       2.395981e-06
# Tot Bwd Pkts      1.866230e-06
# Bwd Pkt Len Std   1.819241e-06
# Flow IAT Std      1.593415e-06
# Bwd Pkt Len Mean  1.580211e-06
# Flow Byts/s       1.297434e-06
# TotLen Fwd Pkts   1.164765e-06
# Fwd Pkt Len Mean  1.355879e-07
# Bwd Pkt Len Max   1.095742e-07
# Fwd Pkt Len Min   0.000000e+00
# Bwd Pkt Len Min   0.000000e+00
#
#
#
# SSH-Bruteforce=["Flow IAT Max","Flow Duration","Flow Pkts/s","Flow IAT Mean","Fwd Pkt Len Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infilteration importance list:
# Infilteration
#                    importance
# Features
# Flow Byts/s         0.063975
# Flow IAT Min        0.056060
# Flow IAT Max        0.049850
# Flow Duration       0.034707
# Flow IAT Mean       0.033322
# Fwd Pkt Len Std     0.030012
# Flow Pkts/s         0.022386
# Flow IAT Std        0.020229
# Fwd IAT Tot         0.016782
# Fwd Pkt Len Max     0.009008
# TotLen Fwd Pkts     0.005003
# Fwd Pkt Len Mean    0.004539
# Bwd Pkt Len Mean    0.004068
# TotLen Bwd Pkts     0.003940
# Bwd Pkt Len Max     0.003653
# Bwd Pkt Len Min     0.003362
# Fwd Pkt Len Min     0.002934
# Tot Fwd Pkts        0.002507
# Bwd Pkt Len Std     0.002368
# Tot Bwd Pkts        0.000531
#
#
#
# Infilteration=["Flow Byts/s","Flow IAT Min","Flow IAT Max","Flow Duration","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS attacks-SlowHTTPTest importance list:
# DoS attacks-SlowHTTPTest
#                    importance
# Features
# Flow Duration       0.001827
# Flow IAT Mean       0.001770
# Flow Pkts/s         0.001731
# Flow IAT Max        0.001726
# Tot Fwd Pkts        0.000000
# Flow IAT Min        0.000000
# Flow IAT Std        0.000000
# Flow Byts/s         0.000000
# Bwd Pkt Len Std     0.000000
# Bwd Pkt Len Mean    0.000000
# Bwd Pkt Len Min     0.000000
# Bwd Pkt Len Max     0.000000
# Fwd Pkt Len Std     0.000000
# Fwd Pkt Len Mean    0.000000
# Fwd Pkt Len Min     0.000000
# Fwd Pkt Len Max     0.000000
# TotLen Bwd Pkts     0.000000
# TotLen Fwd Pkts     0.000000
# Tot Bwd Pkts        0.000000
# Fwd IAT Tot         0.000000
#
#
#
# DoS attacks-SlowHTTPTest=["Flow Duration","Flow IAT Mean","Flow Pkts/s","Flow IAT Max","Tot Fwd Pkts"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS attacks-GoldenEye importance list:
# DoS attacks-GoldenEye
#                      importance
# Features
# Fwd Pkt Len Max   2.020702e-01
# Flow Duration     8.495194e-04
# Flow IAT Max      7.328109e-04
# Fwd IAT Tot       2.778726e-04
# Fwd Pkt Len Std   1.533628e-04
# Fwd Pkt Len Mean  1.450128e-04
# TotLen Fwd Pkts   9.365449e-05
# Flow IAT Mean     3.509040e-05
# Tot Fwd Pkts      3.462655e-05
# Flow Pkts/s       1.862459e-05
# Flow IAT Min      1.693476e-05
# Tot Bwd Pkts      1.094812e-05
# Fwd Pkt Len Min   1.042278e-05
# Flow IAT Std      8.846859e-06
# TotLen Bwd Pkts   6.963809e-06
# Bwd Pkt Len Max   4.837494e-06
# Bwd Pkt Len Mean  4.148685e-06
# Bwd Pkt Len Std   4.141252e-06
# Flow Byts/s       2.534539e-06
# Bwd Pkt Len Min   1.374054e-07
#
#
#
# DoS attacks-GoldenEye=["Fwd Pkt Len Max","Flow Duration","Flow IAT Max","Fwd IAT Tot","Fwd Pkt Len Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS attacks-Slowloris importance list:
# DoS attacks-Slowloris
#                    importance
# Features
# Fwd Pkt Len Max     0.128487
# Fwd Pkt Len Std     0.019226
# Flow Byts/s         0.003300
# Fwd IAT Tot         0.001383
# Flow IAT Min        0.000683
# Flow Duration       0.000366
# Flow IAT Max        0.000343
# Flow IAT Mean       0.000330
# Tot Bwd Pkts        0.000309
# Flow Pkts/s         0.000299
# Bwd Pkt Len Min     0.000253
# Flow IAT Std        0.000157
# Tot Fwd Pkts        0.000033
# Bwd Pkt Len Max     0.000009
# TotLen Bwd Pkts     0.000004
# Bwd Pkt Len Mean    0.000004
# Fwd Pkt Len Min     0.000002
# TotLen Fwd Pkts     0.000002
# Fwd Pkt Len Mean    0.000001
# Bwd Pkt Len Std     0.000000
#
#
#
# DoS attacks-Slowloris=["Fwd Pkt Len Max","Fwd Pkt Len Std","Flow Byts/s","Fwd IAT Tot","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDOS attack-LOIC-UDP importance list:
# DDOS attack-LOIC-UDP
#                    importance
# Features
# Tot Fwd Pkts           0.240
# TotLen Fwd Pkts        0.072
# Flow Duration          0.000
# Bwd Pkt Len Mean       0.000
# Flow IAT Min           0.000
# Flow IAT Max           0.000
# Flow IAT Std           0.000
# Flow IAT Mean          0.000
# Flow Pkts/s            0.000
# Flow Byts/s            0.000
# Bwd Pkt Len Std        0.000
# Bwd Pkt Len Min        0.000
# Bwd Pkt Len Max        0.000
# Fwd Pkt Len Std        0.000
# Fwd Pkt Len Mean       0.000
# Fwd Pkt Len Min        0.000
# Fwd Pkt Len Max        0.000
# TotLen Bwd Pkts        0.000
# Tot Bwd Pkts           0.000
# Fwd IAT Tot            0.000
#
#
#
# DDOS attack-LOIC-UDP=["Tot Fwd Pkts","TotLen Fwd Pkts","Flow Duration","Bwd Pkt Len Mean","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                    importance
# Features
# Flow IAT Max        0.166221
# Fwd Pkt Len Mean    0.159308
# Flow IAT Mean       0.083352
# Flow Duration       0.012946
# Flow IAT Min        0.012562
# Fwd IAT Tot         0.003236
# Flow Byts/s         0.003228
# Bwd Pkt Len Std     0.002430
# TotLen Fwd Pkts     0.001714
# Bwd Pkt Len Max     0.001698
# Flow Pkts/s         0.001311
# Flow IAT Std        0.000831
# Fwd Pkt Len Max     0.000781
# Fwd Pkt Len Std     0.000627
# Tot Fwd Pkts        0.000190
# Tot Bwd Pkts        0.000149
# TotLen Bwd Pkts     0.000052
# Bwd Pkt Len Mean    0.000038
# Bwd Pkt Len Min     0.000034
# Fwd Pkt Len Min     0.000000
#
#
#
# Web Attack=["Flow IAT Max","Fwd Pkt Len Mean","Flow IAT Mean","Flow Duration","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Mission accomplished!
# Total operation time: =  16909.43749165535 seconds
