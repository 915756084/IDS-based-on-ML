# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##  "attacks" folder (with attack csv files) is required for the operation of the program.
##  "attacks" folder must be located in the same directory as the program.


##  the purpose of this code is to determine which features to use in the machine learning phase.
##  for this purpose, the importance weights of the attacks are calculated.
##  this calculation was made using sklearn-RandomForestRegressor.

##  the some codes parts used for calculation and graphing are taken from the following site.
##  http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

def folder(f_name): #this function creates a folder named "feaure_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")
        

# CSV files names:
csv_files=os.listdir("/content/drive/MyDrive/Git/attacks/")# It creates a list of file names in the "attacks" folder.

# Headers of column
main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("/content/drive/MyDrive/Git/feature_pics_attack/")
for j in csv_files:
    df=pd.read_csv("/content/drive/MyDrive/Git/attacks/"+j,usecols=main_labels)
    df.fillna(0, inplace=True)
    df.replace([np.inf, -np.inf], -1, inplace=True)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values
    
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0
   

    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances  
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("/content/drive/MyDrive/Git/feature_pics_attack/"+j[0:-4]+".pdf",bbox_inches='tight', papertype = 'a4', orientation = 'portrait', format = 'pdf')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.378983
# Flow IAT Mean                  0.009960
# Flow IAT Std                   0.008240
# Flow Duration                  0.007968
# Flow IAT Max                   0.007076
# Flow IAT Min                   0.006009
# Fwd IAT Total                  0.000858
# Flow Packets/s                 0.000780
# Flow Bytes/s                   0.000573
# Bwd Packet Length Std          0.000291
# Total Length of Bwd Packets    0.000288
# Total Backward Packets         0.000193
# Bwd Packet Length Max          0.000187
# Fwd Packet Length Mean         0.000114
# Total Length of Fwd Packets    0.000062
# Fwd Packet Length Std          0.000035
# Total Fwd Packets              0.000030
# Fwd Packet Length Max          0.000028
# Bwd Packet Length Min          0.000011
# Fwd Packet Length Min          0.000002
#
#
#
# Bot=["Bwd Packet Length Mean","Flow IAT Mean","Flow IAT Std","Flow Duration","Flow IAT Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Bwd Packet Length Std          0.471112
# Total Backward Packets         0.093254
# Fwd IAT Total                  0.011043
# Total Length of Fwd Packets    0.007493
# Flow Duration                  0.007334
# Flow IAT Min                   0.005901
# Flow IAT Std                   0.005674
# Flow IAT Mean                  0.005469
# Flow IAT Max                   0.004655
# Flow Bytes/s                   0.003054
# Fwd Packet Length Max          0.002132
# Flow Packets/s                 0.001013
# Fwd Packet Length Std          0.000904
# Bwd Packet Length Max          0.000603
# Bwd Packet Length Min          0.000506
# Fwd Packet Length Mean         0.000443
# Bwd Packet Length Mean         0.000182
# Total Length of Bwd Packets    0.000078
# Total Fwd Packets              0.000038
# Fwd Packet Length Min          0.000015
#
#
#
# DDoS=["Bwd Packet Length Std","Total Backward Packets","Fwd IAT Total","Total Length of Fwd Packets","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Bwd Packet Length Std          0.287634
# Flow IAT Max                   0.236573
# Flow IAT Min                   0.146307
# Total Backward Packets         0.021943
# Flow IAT Mean                  0.020003
# Fwd Packet Length Min          0.004578
# Flow IAT Std                   0.003427
# Fwd Packet Length Max          0.001543
# Total Length of Fwd Packets    0.000897
# Flow Duration                  0.000884
# Fwd IAT Total                  0.000774
# Fwd Packet Length Mean         0.000679
# Bwd Packet Length Mean         0.000664
# Flow Bytes/s                   0.000344
# Flow Packets/s                 0.000243
# Bwd Packet Length Max          0.000129
# Total Length of Bwd Packets    0.000113
# Bwd Packet Length Min          0.000073
# Total Fwd Packets              0.000062
# Fwd Packet Length Std          0.000058
#
#
#
# DoS GoldenEye=["Bwd Packet Length Std","Flow IAT Max","Flow IAT Min","Total Backward Packets","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Hulk importance list:
# DoS Hulk
#                                 importance
# Features
# Bwd Packet Length Std        5.150941e-01
# Fwd Packet Length Std        7.679628e-02
# Flow IAT Min                 1.971028e-03
# Flow Duration                1.685130e-03
# Fwd Packet Length Max        8.346111e-04
# Total Backward Packets       2.336023e-04
# Fwd IAT Total                2.135378e-04
# Total Length of Bwd Packets  1.973730e-04
# Flow IAT Max                 1.678050e-04
# Flow IAT Mean                1.117127e-04
# Flow Packets/s               9.914015e-05
# Flow IAT Std                 8.356841e-05
# Flow Bytes/s                 2.458798e-05
# Bwd Packet Length Max        2.394229e-05
# Bwd Packet Length Mean       2.095229e-05
# Fwd Packet Length Mean       1.414206e-05
# Total Fwd Packets            1.127657e-05
# Bwd Packet Length Min        7.060751e-06
# Total Length of Fwd Packets  6.701483e-06
# Fwd Packet Length Min        1.957361e-07
#
#
#
# DoS Hulk=["Bwd Packet Length Std","Fwd Packet Length Std","Flow IAT Min","Flow Duration","Fwd Packet Length Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow IAT Mean                  0.652125
# Fwd Packet Length Min          0.085648
# Bwd Packet Length Mean         0.024222
# Fwd Packet Length Std          0.014851
# Fwd Packet Length Mean         0.011394
# Total Length of Bwd Packets    0.008496
# Bwd Packet Length Max          0.008235
# Bwd Packet Length Std          0.007816
# Flow IAT Min                   0.001619
# Bwd Packet Length Min          0.000874
# Flow Bytes/s                   0.000432
# Flow Duration                  0.000379
# Flow IAT Max                   0.000290
# Fwd IAT Total                  0.000237
# Total Length of Fwd Packets    0.000230
# Fwd Packet Length Max          0.000228
# Total Fwd Packets              0.000219
# Total Backward Packets         0.000177
# Flow IAT Std                   0.000138
# Flow Packets/s                 0.000115
#
#
#
# DoS Slowhttptest=["Flow IAT Mean","Fwd Packet Length Min","Bwd Packet Length Mean","Fwd Packet Length Std","Fwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Flow IAT Mean                  0.474748
# Total Length of Bwd Packets    0.077674
# Bwd Packet Length Mean         0.032453
# Total Fwd Packets              0.022426
# Fwd IAT Total                  0.002142
# Flow Duration                  0.001051
# Flow IAT Min                   0.000817
# Flow Bytes/s                   0.000793
# Flow IAT Max                   0.000743
# Fwd Packet Length Max          0.000711
# Flow Packets/s                 0.000692
# Bwd Packet Length Std          0.000643
# Fwd Packet Length Mean         0.000616
# Total Backward Packets         0.000566
# Bwd Packet Length Max          0.000547
# Flow IAT Std                   0.000542
# Fwd Packet Length Std          0.000540
# Total Length of Fwd Packets    0.000504
# Fwd Packet Length Min          0.000323
# Bwd Packet Length Min          0.000007
#
#
#
# DoS slowloris=["Flow IAT Mean","Total Length of Bwd Packets","Bwd Packet Length Mean","Total Fwd Packets","Fwd IAT Total"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.153664
# Fwd Packet Length Std          0.023257
# Fwd Packet Length Mean         0.017094
# Bwd Packet Length Mean         0.000916
# Bwd Packet Length Max          0.000375
# Flow IAT Min                   0.000297
# Bwd Packet Length Std          0.000154
# Total Length of Fwd Packets    0.000151
# Bwd Packet Length Min          0.000147
# Flow IAT Mean                  0.000097
# Total Length of Bwd Packets    0.000091
# Fwd IAT Total                  0.000077
# Total Fwd Packets              0.000077
# Flow Duration                  0.000063
# Total Backward Packets         0.000062
# Fwd Packet Length Min          0.000051
# Flow IAT Max                   0.000049
# Flow Packets/s                 0.000046
# Flow Bytes/s                   0.000034
# Flow IAT Std                   0.000017
#
#
#
# FTP-Patator=["Fwd Packet Length Max","Fwd Packet Length Std","Fwd Packet Length Mean","Bwd Packet Length Mean","Bwd Packet Length Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Bwd Packet Length Mean            0.052
# Bwd Packet Length Max             0.044
# Total Length of Fwd Packets       0.044
# Total Length of Bwd Packets       0.040
# Bwd Packet Length Std             0.040
# Total Fwd Packets                 0.036
# Total Backward Packets            0.032
# Fwd Packet Length Max             0.028
# Flow Duration                     0.024
# Fwd IAT Total                     0.024
# Flow IAT Min                      0.012
# Fwd Packet Length Std             0.004
# Flow IAT Max                      0.004
# Fwd Packet Length Mean            0.000
# Fwd Packet Length Min             0.000
# Flow Bytes/s                      0.000
# Flow Packets/s                    0.000
# Flow IAT Mean                     0.000
# Flow IAT Std                      0.000
# Bwd Packet Length Min             0.000
#
#
#
# Heartbleed=["Bwd Packet Length Mean","Bwd Packet Length Max","Total Length of Fwd Packets","Total Length of Bwd Packets","Bwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Total Length of Fwd Packets    0.141982
# Fwd Packet Length Mean         0.085064
# Total Backward Packets         0.053020
# Flow IAT Max                   0.023848
# Flow IAT Min                   0.011597
# Fwd Packet Length Std          0.010089
# Fwd Packet Length Max          0.007670
# Flow Bytes/s                   0.005688
# Flow IAT Std                   0.005448
# Fwd IAT Total                  0.005420
# Bwd Packet Length Mean         0.004935
# Bwd Packet Length Max          0.004927
# Flow Duration                  0.004883
# Total Fwd Packets              0.003485
# Bwd Packet Length Std          0.003435
# Bwd Packet Length Min          0.003352
# Flow IAT Mean                  0.002971
# Fwd Packet Length Min          0.002650
# Flow Packets/s                 0.002619
# Total Length of Bwd Packets    0.002167
#
#
#
# Infiltration=["Total Length of Fwd Packets","Fwd Packet Length Mean","Total Backward Packets","Flow IAT Max","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                               importance
# Features
# Flow Bytes/s                   0.315520
# Total Length of Fwd Packets    0.303913
# Flow Duration                  0.000712
# Fwd IAT Total                  0.000659
# Fwd Packet Length Max          0.000171
# Flow IAT Mean                  0.000080
# Flow Packets/s                 0.000050
# Flow IAT Min                   0.000042
# Total Length of Bwd Packets    0.000021
# Flow IAT Max                   0.000019
# Bwd Packet Length Std          0.000019
# Fwd Packet Length Mean         0.000018
# Total Backward Packets         0.000015
# Total Fwd Packets              0.000014
# Flow IAT Std                   0.000011
# Fwd Packet Length Std          0.000010
# Bwd Packet Length Max          0.000003
# Bwd Packet Length Mean         0.000003
# Fwd Packet Length Min          0.000002
# Bwd Packet Length Min          0.000002
#
#
#
# PortScan=["Flow Bytes/s","Total Length of Fwd Packets","Flow Duration","Fwd IAT Total","Fwd Packet Length Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.000903
# Flow IAT Max                   0.000636
# Total Length of Fwd Packets    0.000627
# Flow Duration                  0.000620
# Flow IAT Mean                  0.000386
# Flow Packets/s                 0.000350
# Flow Bytes/s                   0.000345
# Flow IAT Std                   0.000335
# Fwd IAT Total                  0.000322
# Fwd Packet Length Mean         0.000235
# Fwd Packet Length Min          0.000152
# Bwd Packet Length Min          0.000136
# Fwd Packet Length Std          0.000099
# Flow IAT Min                   0.000099
# Total Fwd Packets              0.000061
# Bwd Packet Length Mean         0.000041
# Total Backward Packets         0.000032
# Bwd Packet Length Max          0.000030
# Total Length of Bwd Packets    0.000028
# Bwd Packet Length Std          0.000026
#
#
#
# SSH-Patator=["Fwd Packet Length Max","Flow IAT Max","Total Length of Fwd Packets","Flow Duration","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Bwd Packet Length Std          0.005996
# Total Length of Fwd Packets    0.005362
# Flow Bytes/s                   0.002219
# Flow IAT Min                   0.001727
# Total Fwd Packets              0.001575
# Bwd Packet Length Max          0.001318
# Fwd Packet Length Std          0.001168
# Fwd Packet Length Mean         0.000971
# Fwd Packet Length Max          0.000560
# Flow Duration                  0.000522
# Flow Packets/s                 0.000444
# Flow IAT Mean                  0.000425
# Flow IAT Max                   0.000403
# Total Backward Packets         0.000211
# Total Length of Bwd Packets    0.000125
# Flow IAT Std                   0.000094
# Bwd Packet Length Mean         0.000092
# Fwd IAT Total                  0.000085
# Bwd Packet Length Min          0.000060
# Fwd Packet Length Min          0.000002
#
#
#
# Web Attack=["Bwd Packet Length Std","Total Length of Fwd Packets","Flow Bytes/s","Flow IAT Min","Total Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  6262.6157257556915 seconds
